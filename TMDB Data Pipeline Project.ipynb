# %%
import requests

url = "https://api.themoviedb.org/3/configuration"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}

response = requests.get(url, headers=headers)

tmdb = response.text

# %%
print(tmdb)
# Out:
# {"change_keys":["adult","air_date","also_known_as","alternative_titles","biography","birthday","budget","cast","certifications","character_names","created_by","crew","deathday","episode","episode_number","episode_run_time","freebase_id","freebase_mid","general","genres","guest_stars","homepage","images","imdb_id","languages","name","network","origin_country","original_name","original_title","overview","parts","place_of_birth","plot_keywords","production_code","production_companies","production_countries","releases","revenue","runtime","season","season_number","season_regular","spoken_languages","status","tagline","title","translations","tvdb_id","tvrage_id","type","video","videos"],"images":{"base_url":"http://image.tmdb.org/t/p/","secure_base_url":"https://image.tmdb.org/t/p/","backdrop_sizes":["w300","w780","w1280","original"],"logo_sizes":["w45","w92","w154","w185","w300","w500","original"],"poster_sizes":["w92","w154","w185","w342","w500","w780","original"],"profile_sizes":["w45"
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/pNjh59JSxChQktamG3LMp9ZoQzp.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":28.365,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.712,"vote_count":28628},{"adult":false,"backdrop_path":"/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fic
# ...

# %%
import requests
import pandas as pd
import time
# !pip install tqdm
from tqdm import tqdm

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}

response = requests.get(url, headers=headers)

print(response.json())

top_movies = response
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/pNjh59JSxChQktamG3LMp9ZoQzp.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 28.365, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.712, 'vote_count': 28628}, {'adult': False, 'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning 
# ...

# %%
top_movies.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 top_movies.split()
#
# AttributeError: 'Response' object has no attribute 'split'

# %%
top_movies.split("/")[::]
# Out:
# ['{"page":1,"results":[{"adult":false,"backdrop_path":"',
#  'pNjh59JSxChQktamG3LMp9ZoQzp.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":28.365,"poster_path":"',
#  '9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.712,"vote_count":28628},{"adult":false,"backdrop_path":"',
# ...

# %%
chunk_data = top_movies.split("/")[::]

# %%
len(chunk_data)
# Out:
# 41

# %%
slim_data = chunk_data[1:2:1]

# %%
slim_data
# Out:
# ['pNjh59JSxChQktamG3LMp9ZoQzp.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":28.365,"poster_path":"']

# %%
slim_data[0][54:61]
# Out:
# 'id":278'

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}
all_results = []

page = 1
response = requests.get(f"{url}&page={page}", headers=headers)
data = response.json()

total_pages = data["total_pages"]
all_results.extend(data["results"])

max_pages = min(total_pages,500)

for page in range(2, max_pages + 1):
    response = requests.get(f"{url}&page={page}", headers=headers)
    data = response.json()
    all_results.extend(data["results"])
    time.sleep(.25)
    print(f"Total top movies retrieved:{len(all_results)}")
# Out:
# Total top movies retrieved:40
# Total top movies retrieved:60
# Total top movies retrieved:80
# Total top movies retrieved:100
# Total top movies retrieved:120
# Total top movies retrieved:140
# Total top movies retrieved:160
# Total top movies retrieved:180
# Total top movies retrieved:200
# Total top movies retrieved:220
# Total top movies retrieved:240
# Total top movies retrieved:260
# Total top movies retrieved:280
# Total top movies retrieved:300
# Total top movies retrieved:320
# Total top movies retrieved:340
# Total top movies retrieved:360
# Total top movies retrieved:380
# Total top movies retrieved:400
# Total top movies retrieved:420
# Total top movies retrieved:440
# Total top movies retrieved:460
# Total top movies retrieved:480
# Total top movies retrieved:500
# Total top movies retrieved:520
# Total top movies retrieved:540
# Total top movies retrieved:560
# Total top movies retrieved:580
# Total top movies retrieved:600
# Total top movies retrieved:620
# ...

# %%
for movie in all_results[:220]:
    print(movie['title'])
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather Part II
# Schindler's List
# 12 Angry Men
# Spirited Away
# The Dark Knight
# Dilwale Dulhania Le Jayenge
# The Green Mile
# Parasite
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# Your Name.
# Forrest Gump
# The Good, the Bad and the Ugly
# KPop Demon Hunters
# Interstellar
# Seven Samurai
# GoodFellas
# Grave of the Fireflies
# Life Is Beautiful
# Fight Club
# Cinema Paradiso
# Impossible Things
# City of God
# A Dog's Will
# Harakiri
# The Lord of the Rings: The Fellowship of the Ring
# Psycho
# One Flew Over the Cuckoo's Nest
# Gabriel's Inferno
# Once Upon a Time in America
# The Lord of the Rings: The Two Towers
# Hope
# Spider-Man: Into the Spider-Verse
# Howl's Moving Castle
# The Empire Strikes Back
# Primal: Tales of Savagery
# A Silent Voice: The Movie
# The Pianist
# Gabriel's Inferno: Part II
# Whiplash
# Se7en
# Gabriel's Inferno: Part III
# Lucy Shimmers and the Prince of Peace
# Inception
# ...

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}
all_results = []

page = 1
response = requests.get(f"{url}&page={page}", headers=headers)
data = response.json()

total_pages = data["total_pages"]
all_results.extend(data["results"])

# %%
for movie in all_results[:15]:
    print(movie['title'])
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather Part II
# Schindler's List
# 12 Angry Men
# Spirited Away
# The Dark Knight
# Dilwale Dulhania Le Jayenge
# The Green Mile
# Parasite
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# Your Name.
# Forrest Gump
# The Good, the Bad and the Ugly

# %%
all_results[1]['original_title']
# Out:
# 'The Godfather'

# %%
all_results[1]['title']
# Out:
# 'The Godfather'

# %%
all_results[1]['id']
# Out:
# 238

# %%
all_results[1]['original_language']
# Out:
# 'en'

# %%
for row in all_results[:]:
    original_title = row['original_title']
    title = row['title']
    original_language = row['original_language']
    id_number = row['id']
    movie_element = {'original_title':original_title, 'title':title, 'original_language':original_language, 
                     'id':id_number}
    print(movie_element)
# Out:
# {'original_title': 'The Shawshank Redemption', 'title': 'The Shawshank Redemption', 'original_language': 'en', 'id': 278}
# {'original_title': 'The Godfather', 'title': 'The Godfather', 'original_language': 'en', 'id': 238}
# {'original_title': 'The Godfather Part II', 'title': 'The Godfather Part II', 'original_language': 'en', 'id': 240}
# {'original_title': "Schindler's List", 'title': "Schindler's List", 'original_language': 'en', 'id': 424}
# {'original_title': '12 Angry Men', 'title': '12 Angry Men', 'original_language': 'en', 'id': 389}
# {'original_title': '千と千尋の神隠し', 'title': 'Spirited Away', 'original_language': 'ja', 'id': 129}
# {'original_title': 'The Dark Knight', 'title': 'The Dark Knight', 'original_language': 'en', 'id': 155}
# {'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'title': 'Dilwale Dulhania Le Jayenge', 'original_language': 'hi', 'id': 19404}
# {'original_title': 'The Green Mile', 'title': 'The Green Mile', 'original_language': 'en', 'id': 497}
# ...

# %%
top_movies_list = []
for row in all_results[:]:
    original_title = row['original_title']
    title = row['title']
    original_language = row['original_language']
    id_number = row['id']
    movie_element = {'original_title':original_title, 'title':title, 'original_language':original_language, 
                     'id':id_number}
    top_movies_list.append(movie_element)

# %%
top_movies_list
# Out:
# [{'original_title': 'The Shawshank Redemption',
#   'title': 'The Shawshank Redemption',
#   'original_language': 'en',
#   'id': 278},
#  {'original_title': 'The Godfather',
#   'title': 'The Godfather',
#   'original_language': 'en',
#   'id': 238},
#  {'original_title': 'The Godfather Part II',
#   'title': 'The Godfather Part II',
#   'original_language': 'en',
#   'id': 240},
#  {'original_title': "Schindler's List",
#   'title': "Schindler's List",
#   'original_language': 'en',
#   'id': 424},
#  {'original_title': '12 Angry Men',
#   'title': '12 Angry Men',
#   'original_language': 'en',
#   'id': 389},
#  {'original_title': '千と千尋の神隠し',
#   'title': 'Spirited Away',
#   'original_language': 'ja',
#   'id': 129},
#  {'original_title': 'The Dark Knight',
#   'title': 'The Dark Knight',
#   'original_language': 'en',
#   'id': 155},
#  {'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'original_language': 'hi',
#   'id': 19404},
# ...

# %%
sliced_top_movies = list(top_movies.items())

# %%
sliced_top_movies
# Out:
# [('page', 500),
#  ('results',
#   [{'adult': False,
#     'backdrop_path': '/mZT5eXy9Tapf85LV62hkfaVp2Of.jpg',
#     'genre_ids': [28, 18],
#     'id': 308529,
#     'original_language': 'en',
#     'original_title': 'Kickboxer: Vengeance',
#     'overview': "Eric and Kurt Sloane are the descendants of a well-known Venice, California-based family of martial artists. Kurt has always been in older brother, Eric's shadow, as he lacks the instincts needed to become a champion. Against Kurt's concerns, Eric accepts a paid offer and travels to Thailand to challenge the Muay Thai champion Tong Po and fails with dire consequences. Kurt sets out for revenge. He trains with his brother's mentor, Master Durand, for a Muay Thai fight against the merciless champion, Tong Po. Durand first thinks Kurt is impossible to train, but through a series of spiritual exercises and tests, Durand discovers that Kurt has a deeper strength that will carry him through his final showdown with Tong Po.",
# ...

# %%
len(sliced_top_movies)
# Out:
# 4

# %%
len(sliced_top_movies[1][1])
# Out:
# 20

# %%
sliced_top_movies[1][1][0]['original_title']
# Out:
# 'Kickboxer: Vengeance'

# %%
all_results[1]['vote_count']
# Out:
# 21676

# %%
all_results[1]['vote_average']
# Out:
# 8.686

# %%
all_results[1]['popularity']
# Out:
# 28.2502

# %%
all_results[1]['release_date']
# Out:
# '1972-03-14'

# %%
for row in all_results[:]:
    title = row['title']
    vote_count= row['vote_count']
    vote_average = row['vote_average']
    popularity = row['popularity']
    release_date = row['release_date']
    movie_data_element = {'title': title, 'vote_count': vote_count, 'vote_average': vote_average,
                         'popularity': popularity, 'release_date': release_date}
    print(movie_data_element)
# Out:
# {'title': 'The Shawshank Redemption', 'vote_count': 28628, 'vote_average': 8.712, 'popularity': 38.5399, 'release_date': '1994-09-23'}
# {'title': 'The Godfather', 'vote_count': 21676, 'vote_average': 8.686, 'popularity': 28.2502, 'release_date': '1972-03-14'}
# {'title': 'The Godfather Part II', 'vote_count': 13087, 'vote_average': 8.571, 'popularity': 17.3499, 'release_date': '1974-12-20'}
# {'title': "Schindler's List", 'vote_count': 16594, 'vote_average': 8.565, 'popularity': 16.2378, 'release_date': '1993-12-15'}
# {'title': '12 Angry Men', 'vote_count': 9292, 'vote_average': 8.549, 'popularity': 14.94, 'release_date': '1957-04-10'}
# {'title': 'Spirited Away', 'vote_count': 17333, 'vote_average': 8.536, 'popularity': 18.8238, 'release_date': '2001-07-20'}
# {'title': 'The Dark Knight', 'vote_count': 34165, 'vote_average': 8.522, 'popularity': 24.8401, 'release_date': '2008-07-16'}
# ...

# %%
movie_data_list = []
for row in all_results[:]:
    title = row['title']
    vote_count= row['vote_count']
    vote_average = row['vote_average']
    popularity = row['popularity']
    release_date = row['release_date']
    movie_data_element = {'title': title, 'vote_count': vote_count, 'vote_average': vote_average,
                         'popularity': popularity, 'release_date': release_date}
    movie_data_list.append(movie_data_element)

# %%
movie_data_list
# Out:
# [{'title': 'The Shawshank Redemption',
#   'vote_count': 28628,
#   'vote_average': 8.712,
#   'popularity': 38.5399,
#   'release_date': '1994-09-23'},
#  {'title': 'The Godfather',
#   'vote_count': 21676,
#   'vote_average': 8.686,
#   'popularity': 28.2502,
#   'release_date': '1972-03-14'},
#  {'title': 'The Godfather Part II',
#   'vote_count': 13087,
#   'vote_average': 8.571,
#   'popularity': 17.3499,
#   'release_date': '1974-12-20'},
#  {'title': "Schindler's List",
#   'vote_count': 16594,
#   'vote_average': 8.565,
#   'popularity': 16.2378,
#   'release_date': '1993-12-15'},
#  {'title': '12 Angry Men',
#   'vote_count': 9292,
#   'vote_average': 8.549,
#   'popularity': 14.94,
#   'release_date': '1957-04-10'},
#  {'title': 'Spirited Away',
#   'vote_count': 17333,
#   'vote_average': 8.536,
#   'popularity': 18.8238,
#   'release_date': '2001-07-20'},
#  {'title': 'The Dark Knight',
#   'vote_count': 34165,
#   'vote_average': 8.522,
#   'popularity': 24.8401,
# ...

# %%
top_movies_df = pd.DataFrame.from_dict(top_movies_list)

# %%
top_movies_df.head()
# Out:
#              original_title                     title original_language   id
# 0  The Shawshank Redemption  The Shawshank Redemption                en  278
# 1             The Godfather             The Godfather                en  238
# 2     The Godfather Part II     The Godfather Part II                en  240
# 3          Schindler's List          Schindler's List                en  424
# 4              12 Angry Men              12 Angry Men                en  389

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     20 non-null     object
#  1   title              20 non-null     object
#  2   original_language  20 non-null     object
#  3   id                 20 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 768.0+ bytes

# %%
top_movies_df = top_movies_df.drop_duplicates(subset=['id'])

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     20 non-null     object
#  1   title              20 non-null     object
#  2   original_language  20 non-null     object
#  3   id                 20 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 800.0+ bytes

# %%
movie_data_df = pd.DataFrame.from_dict(movie_data_list)

# %%
movie_data_df.head()
# Out:
#                       title  vote_count  vote_average  popularity release_date
# 0  The Shawshank Redemption       28628         8.712     38.5399   1994-09-23
# 1             The Godfather       21676         8.686     28.2502   1972-03-14
# 2     The Godfather Part II       13087         8.571     17.3499   1974-12-20
# 3          Schindler's List       16594         8.565     16.2378   1993-12-15
# 4              12 Angry Men        9292         8.549     14.9400   1957-04-10

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         20 non-null     object
#  1   vote_count    20 non-null     int64
#  2   vote_average  20 non-null     float64
#  3   popularity    20 non-null     float64
#  4   release_date  20 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 928.0+ bytes

# %%
movie_data_df = movie_data_df.drop_duplicates(subset=['title'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         20 non-null     object
#  1   vote_count    20 non-null     int64
#  2   vote_average  20 non-null     float64
#  3   popularity    20 non-null     float64
#  4   release_date  20 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 960.0+ bytes

# %%
movie_data_df['release_date'] = pd.to_datetime(movie_data_df['release_date'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         20 non-null     object
#  1   vote_count    20 non-null     int64
#  2   vote_average  20 non-null     float64
#  3   popularity    20 non-null     float64
#  4   release_date  20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 960.0+ bytes

# %%
movie_data_df.head()
# Out:
#                       title  vote_count  vote_average  popularity release_date
# 0  The Shawshank Redemption       28628         8.712     38.5399   1994-09-23
# 1             The Godfather       21676         8.686     28.2502   1972-03-14
# 2     The Godfather Part II       13087         8.571     17.3499   1974-12-20
# 3          Schindler's List       16594         8.565     16.2378   1993-12-15
# 4              12 Angry Men        9292         8.549     14.9400   1957-04-10

# %%
#testing top_movies for all 500 pages and the two new data frames, 'top_movie_list' and 'movie_data_list'

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}
all_results = []

page = 1
response = requests.get(f"{url}&page={page}", headers=headers)
data = response.json()

total_pages = data["total_pages"]
all_results.extend(data["results"])

max_pages = min(total_pages,500)

for page in range(2, max_pages + 1):
    response = requests.get(f"{url}&page={page}", headers=headers)
    data = response.json()
    all_results.extend(data["results"])
    time.sleep(.25)
    print(f"Total top movies retrieved:{len(all_results)}")
# Out:
# Total top movies retrieved:40
# Total top movies retrieved:60
# Total top movies retrieved:80
# Total top movies retrieved:100
# Total top movies retrieved:120
# Total top movies retrieved:140
# Total top movies retrieved:160
# Total top movies retrieved:180
# Total top movies retrieved:200
# Total top movies retrieved:220
# Total top movies retrieved:240
# Total top movies retrieved:260
# Total top movies retrieved:280
# Total top movies retrieved:300
# Total top movies retrieved:320
# Total top movies retrieved:340
# Total top movies retrieved:360
# Total top movies retrieved:380
# Total top movies retrieved:400
# Total top movies retrieved:420
# Total top movies retrieved:440
# Total top movies retrieved:460
# Total top movies retrieved:480
# Total top movies retrieved:500
# Total top movies retrieved:520
# Total top movies retrieved:540
# Total top movies retrieved:560
# Total top movies retrieved:580
# Total top movies retrieved:600
# Total top movies retrieved:620
# ...

# %%
for row in all_results[:]:
    original_title = row['original_title']
    title = row['title']
    original_language = row['original_language']
    id_number = row['id']
    movie_element = {'original_title':original_title, 'title':title, 'original_language':original_language, 
                     'id':id_number}
    print(movie_element)
# Out:
# {'original_title': 'The Shawshank Redemption', 'title': 'The Shawshank Redemption', 'original_language': 'en', 'id': 278}
# {'original_title': 'The Godfather', 'title': 'The Godfather', 'original_language': 'en', 'id': 238}
# {'original_title': 'The Godfather Part II', 'title': 'The Godfather Part II', 'original_language': 'en', 'id': 240}
# {'original_title': "Schindler's List", 'title': "Schindler's List", 'original_language': 'en', 'id': 424}
# {'original_title': '12 Angry Men', 'title': '12 Angry Men', 'original_language': 'en', 'id': 389}
# {'original_title': '千と千尋の神隠し', 'title': 'Spirited Away', 'original_language': 'ja', 'id': 129}
# {'original_title': 'The Dark Knight', 'title': 'The Dark Knight', 'original_language': 'en', 'id': 155}
# {'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'title': 'Dilwale Dulhania Le Jayenge', 'original_language': 'hi', 'id': 19404}
# {'original_title': 'The Green Mile', 'title': 'The Green Mile', 'original_language': 'en', 'id': 497}
# ...

# %%
top_movies_list = []
for row in all_results[:]:
    original_title = row['original_title']
    title = row['title']
    original_language = row['original_language']
    id_number = row['id']
    movie_element = {'original_title':original_title, 'title':title, 'original_language':original_language, 
                     'id':id_number}
    top_movies_list.append(movie_element)

# %%
print(len(all_results))
# Out:
# 10000

# %%
top_movies_df = pd.DataFrame.from_dict(top_movies_list)

# %%
top_movies_df.head(25)
# Out:
#                                    original_title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# 5                                        千と千尋の神隠し
# 6                                 The Dark Knight
# 7                    दिलवाले दुल्हनिया ले जायेंगे
# 8                                  The Green Mile
# 9                                             기생충
# 10  The Lord of the Rings: The Return of the King
# 11                                   Pulp Fiction
# 12                                          君の名は。
# 13                                   Forrest Gump
# 14                Il buono, il brutto, il cattivo
# 15                                   Interstellar
# 16                                           七人の侍
# 17                                     GoodFellas
# ...

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     10000 non-null  object
#  1   title              10000 non-null  object
#  2   original_language  10000 non-null  object
#  3   id                 10000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
top_movies_df = top_movies_df.drop_duplicates(subset=['id'])

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9998 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     9998 non-null   object
#  1   title              9998 non-null   object
#  2   original_language  9998 non-null   object
#  3   id                 9998 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 390.5+ KB

# %%
top_movies_df.head(5000)
# Out:
#                                original_title  \
# 0                    The Shawshank Redemption
# 1                               The Godfather
# 2                       The Godfather Part II
# 3                            Schindler's List
# 4                                12 Angry Men
# ...                                       ...
# 4996                                   Ransom
# 4997                            Planet Terror
# 4998                          Happy Gilmore 2
# 4999                                Samaritan
# 5000  Tadeo Jones 2: El secreto del rey Midas
#
#                                                   title original_language  \
# 0                              The Shawshank Redemption                en
# 1                                         The Godfather                en
# 2                                 The Godfather Part II                en
# 3                                      Schindler's List                en
# ...

# %%
#now to test 'movie_data_list' we have line 221 loaded with 10k results

# %%
movie_data_list = []
for row in all_results[:]:
    title = row['title']
    vote_count= row['vote_count']
    vote_average = row['vote_average']
    popularity = row['popularity']
    release_date = row['release_date']
    movie_data_element = {'title': title, 'vote_count': vote_count, 'vote_average': vote_average,
                         'popularity': popularity, 'release_date': release_date}
    movie_data_list.append(movie_data_element)

# %%
movie_data_list
# Out:
# [{'title': 'The Shawshank Redemption',
#   'vote_count': 28647,
#   'vote_average': 8.712,
#   'popularity': 32.0375,
#   'release_date': '1994-09-23'},
#  {'title': 'The Godfather',
#   'vote_count': 21684,
#   'vote_average': 8.686,
#   'popularity': 30.3571,
#   'release_date': '1972-03-14'},
#  {'title': 'The Godfather Part II',
#   'vote_count': 13092,
#   'vote_average': 8.571,
#   'popularity': 16.152,
#   'release_date': '1974-12-20'},
#  {'title': "Schindler's List",
#   'vote_count': 16603,
#   'vote_average': 8.566,
#   'popularity': 18.4964,
#   'release_date': '1993-12-15'},
#  {'title': '12 Angry Men',
#   'vote_count': 9297,
#   'vote_average': 8.549,
#   'popularity': 15.0945,
#   'release_date': '1957-04-10'},
#  {'title': 'Spirited Away',
#   'vote_count': 17341,
#   'vote_average': 8.536,
#   'popularity': 18.8253,
#   'release_date': '2001-07-20'},
#  {'title': 'The Dark Knight',
#   'vote_count': 34173,
#   'vote_average': 8.5,
#   'popularity': 27.3757,
# ...

# %%
movie_data_df = pd.DataFrame.from_dict(movie_data_list)

# %%
movie_data_df.head(25)
# Out:
#                                             title  vote_count  vote_average  \
# 0                        The Shawshank Redemption       28647         8.712
# 1                                   The Godfather       21684         8.686
# 2                           The Godfather Part II       13092         8.571
# 3                                Schindler's List       16603         8.566
# 4                                    12 Angry Men        9297         8.549
# 5                                   Spirited Away       17341         8.536
# 6                                 The Dark Knight       34173         8.500
# 7                     Dilwale Dulhania Le Jayenge        4499         8.516
# 8                                  The Green Mile       18260         8.503
# 9                                        Parasite       19325         8.499
# 10  The Lord of the Rings: The Return of the King       25312         8.488
# ...

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10000 non-null  object
#  1   vote_count    10000 non-null  int64
#  2   vote_average  10000 non-null  float64
#  3   popularity    10000 non-null  float64
#  4   release_date  10000 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 390.8+ KB

# %%
movie_data_df = movie_data_df.drop_duplicates(subset=['title'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9628 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         9628 non-null   object
#  1   vote_count    9628 non-null   int64
#  2   vote_average  9628 non-null   float64
#  3   popularity    9628 non-null   float64
#  4   release_date  9628 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 451.3+ KB

# %%
movie_data_df['release_date'] = pd.to_datetime(movie_data_df['release_date'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9628 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         9628 non-null   object
#  1   vote_count    9628 non-null   int64
#  2   vote_average  9628 non-null   float64
#  3   popularity    9628 non-null   float64
#  4   release_date  9628 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 451.3+ KB

# %%
movie_data_df.head(25)
# Out:
#                                             title  vote_count  vote_average  \
# 0                        The Shawshank Redemption       28647         8.712
# 1                                   The Godfather       21684         8.686
# 2                           The Godfather Part II       13092         8.571
# 3                                Schindler's List       16603         8.566
# 4                                    12 Angry Men        9297         8.549
# 5                                   Spirited Away       17341         8.536
# 6                                 The Dark Knight       34173         8.500
# 7                     Dilwale Dulhania Le Jayenge        4499         8.516
# 8                                  The Green Mile       18260         8.503
# 9                                        Parasite       19325         8.499
# 10  The Lord of the Rings: The Return of the King       25312         8.488
# ...

# %%
#end of testing 10k results from tmdb

# %%
# just to test n number of pages for the "top_movie_list"

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}
all_results = []

page = 1
response = requests.get(f"{url}&page={page}", headers=headers)
data = response.json()

total_pages = data["total_pages"]
all_results.extend(data["results"])

max_pages = min(total_pages,5)

for page in range(2, max_pages + 1):
    response = requests.get(f"{url}&page={page}", headers=headers)
    data = response.json()
    all_results.extend(data["results"])
    time.sleep(.25)
    print(f"Total top movies retrieved:{len(all_results)}")
# Out:
# Total top movies retrieved:40
# Total top movies retrieved:60
# Total top movies retrieved:80
# Total top movies retrieved:100

# %%
for movie in all_results[:220]:
    print(movie['title'])
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather Part II
# Schindler's List
# 12 Angry Men
# Spirited Away
# The Dark Knight
# Dilwale Dulhania Le Jayenge
# The Green Mile
# Parasite
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# Your Name.
# Forrest Gump
# The Good, the Bad and the Ugly
# Interstellar
# Seven Samurai
# GoodFellas
# Grave of the Fireflies
# Life Is Beautiful
# Fight Club
# Cinema Paradiso
# Impossible Things
# Harakiri
# City of God
# KPop Demon Hunters
# A Dog's Will
# The Lord of the Rings: The Fellowship of the Ring
# Psycho
# One Flew Over the Cuckoo's Nest
# Gabriel's Inferno
# Once Upon a Time in America
# The Lord of the Rings: The Two Towers
# Spider-Man: Into the Spider-Verse
# Hope
# Howl's Moving Castle
# The Empire Strikes Back
# Primal: Tales of Savagery
# A Silent Voice: The Movie
# The Pianist
# Gabriel's Inferno: Part II
# Whiplash
# Se7en
# Gabriel's Inferno: Part III
# Lucy Shimmers and the Prince of Peace
# Inception
# ...

# %%
print(len(all_results))
# Out:
# 100

# %%
top_movies_list = []
for row in all_results[:]:
    original_title = row['original_title']
    title = row['title']
    original_language = row['original_language']
    id_number = row['id']
    movie_element = {'original_title':original_title, 'title':title, 'original_language':original_language, 
                     'id':id_number}
    top_movies_list.append(movie_element)

# %%
print(len(all_results))
# Out:
# 100

# %%
top_movies_df = pd.DataFrame.from_dict(top_movies_list)

# %%
top_movies_df.head(100)
# Out:
#               original_title                     title original_language  \
# 0   The Shawshank Redemption  The Shawshank Redemption                en
# 1              The Godfather             The Godfather                en
# 2      The Godfather Part II     The Godfather Part II                en
# 3           Schindler's List          Schindler's List                en
# 4               12 Angry Men              12 Angry Men                en
# ..                       ...                       ...               ...
# 95           Five Feet Apart           Five Feet Apart                en
# 96                The Matrix                The Matrix                en
# 97              Иди и смотри              Come and See                ru
# 98               Il sorpasso               Il Sorpasso                it
# 99          Ultraman: Rising          Ultraman: Rising                en
#
#         id
# 0      278
# 1      238
# 2      240
# 3      424
# 4      389
# ..     ...
# ...

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     100 non-null    object
#  1   title              100 non-null    object
#  2   original_language  100 non-null    object
#  3   id                 100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB

# %%
top_movies_df = top_movies_df.drop_duplicates(subset=['id'])

# %%
top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     100 non-null    object
#  1   title              100 non-null    object
#  2   original_language  100 non-null    object
#  3   id                 100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.9+ KB

# %%
top_movies_df.head(100)
# Out:
#               original_title                     title original_language  \
# 0   The Shawshank Redemption  The Shawshank Redemption                en
# 1              The Godfather             The Godfather                en
# 2      The Godfather Part II     The Godfather Part II                en
# 3           Schindler's List          Schindler's List                en
# 4               12 Angry Men              12 Angry Men                en
# ..                       ...                       ...               ...
# 95           Five Feet Apart           Five Feet Apart                en
# 96                The Matrix                The Matrix                en
# 97              Иди и смотри              Come and See                ru
# 98               Il sorpasso               Il Sorpasso                it
# 99          Ultraman: Rising          Ultraman: Rising                en
#
#         id
# 0      278
# 1      238
# 2      240
# 3      424
# 4      389
# ..     ...
# ...

# %%
# just to test n number of pages for the "movie_data_list"

# %%
movie_data_list = []
for row in all_results[:]:
    title = row['title']
    vote_count= row['vote_count']
    vote_average = row['vote_average']
    popularity = row['popularity']
    release_date = row['release_date']
    movie_data_element = {'title': title, 'vote_count': vote_count, 'vote_average': vote_average,
                         'popularity': popularity, 'release_date': release_date}
    movie_data_list.append(movie_data_element)

# %%
print(len(all_results))
# Out:
# 100

# %%
movie_data_df = pd.DataFrame.from_dict(movie_data_list)

# %%
movie_data_df.head(100)
# Out:
#                        title  vote_count  vote_average  popularity  \
# 0   The Shawshank Redemption       28670         8.712     30.1019
# 1              The Godfather       21699         8.686     27.6438
# 2      The Godfather Part II       13098         8.571     15.8254
# 3           Schindler's List       16613         8.566     13.6979
# 4               12 Angry Men        9306         8.549     15.2506
# ..                       ...         ...           ...         ...
# 95           Five Feet Apart        5762         8.232      6.9242
# 96                The Matrix       26646         8.230     17.9241
# 97              Come and See        1650         8.229      5.0114
# 98               Il Sorpasso         802         8.229      1.4770
# 99          Ultraman: Rising         338         8.228      3.8037
#
#    release_date
# 0    1994-09-23
# 1    1972-03-14
# 2    1974-12-20
# 3    1993-12-15
# 4    1957-04-10
# ..          ...
# 95   2019-03-14
# 96   1999-03-31
# ...

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         100 non-null    object
#  1   vote_count    100 non-null    int64
#  2   vote_average  100 non-null    float64
#  3   popularity    100 non-null    float64
#  4   release_date  100 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 4.0+ KB

# %%
movie_data_df = movie_data_df.drop_duplicates(subset=['title'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         100 non-null    object
#  1   vote_count    100 non-null    int64
#  2   vote_average  100 non-null    float64
#  3   popularity    100 non-null    float64
#  4   release_date  100 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 4.7+ KB

# %%
movie_data_df['release_date'] = pd.to_datetime(movie_data_df['release_date'])

# %%
movie_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         100 non-null    object
#  1   vote_count    100 non-null    int64
#  2   vote_average  100 non-null    float64
#  3   popularity    100 non-null    float64
#  4   release_date  100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 4.7+ KB

# %%
movie_data_df.head(100)
# Out:
#                        title  vote_count  vote_average  popularity  \
# 0   The Shawshank Redemption       28670         8.712     30.1019
# 1              The Godfather       21699         8.686     27.6438
# 2      The Godfather Part II       13098         8.571     15.8254
# 3           Schindler's List       16613         8.566     13.6979
# 4               12 Angry Men        9306         8.549     15.2506
# ..                       ...         ...           ...         ...
# 95           Five Feet Apart        5762         8.232      6.9242
# 96                The Matrix       26646         8.230     17.9241
# 97              Come and See        1650         8.229      5.0114
# 98               Il Sorpasso         802         8.229      1.4770
# 99          Ultraman: Rising         338         8.228      3.8037
#
#    release_date
# 0    1994-09-23
# 1    1972-03-14
# 2    1974-12-20
# 3    1993-12-15
# 4    1957-04-10
# ..          ...
# 95   2019-03-14
# 96   1999-03-31
# ...

# %%
#end of testing n number of results from tmdb

# %%
#this is the version of the tmdb api that is being used as "raw data"

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmYzc2MmE5MTBkYjg0MTY3Yzc5NjAxM2VmOTMwZjZhZiIsIm5iZiI6MTc1NDI5MDI3Mi45NzQwMDAyLCJzdWIiOiI2ODkwNTg2MGVhYTRmMzA2ZTA3Y2ZiYWUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.bhX-SZmsVtmxoNAPokTBvwMkmlC4jUbNXzh2oq5R9-U"
}
all_results = []

page = 1
response = requests.get(f"{url}&page={page}", headers=headers)
data = response.json()

total_pages = data["total_pages"]
all_results.extend(data["results"])

max_pages = min(total_pages,5)

for page in range(2, max_pages + 1):
    response = requests.get(f"{url}&page={page}", headers=headers)
    data = response.json()
    all_results.extend(data["results"])
    time.sleep(.25)

# %%
all_results
# Out:
# [{'adult': False,
#   'backdrop_path': '/pNjh59JSxChQktamG3LMp9ZoQzp.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 26.9579,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.712,
#   'vote_count': 28680},
#  {'adult': False,
#   'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
sp.playlist_tracks(playlist_URI)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6VOedaf3eNWDOVpa9Qdlvg/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-03-07T07:49:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#     'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#     'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#     'type': 'user',
#     'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][1]
# Out:
# {'added_at': '2025-05-10T16:34:06Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#   'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#   'type': 'user',
#   'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
# ...

# %%
len(data['items'])
# Out:
# 75

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6xUYw5goKIoyJQi9C27UBy'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'NUNCA MUDA?'

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dDNNq04RjKXFOADdHd6VX'},
#   'href': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX',
#   'id': '5dDNNq04RjKXFOADdHd6VX',
#   'name': 'Scythermane',
#   'type': 'artist',
#   'uri': 'spotify:artist:5dDNNq04RjKXFOADdHd6VX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7lAaAGxYxk2GH8cMbTEwAL'},
#   'href': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL',
#   'id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'name': 'NXGHT!',
#   'type': 'artist',
#   'uri': 'spotify:artist:7lAaAGxYxk2GH8cMbTEwAL'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/14hsjenLEdvafsGkk2CEiF'},
#   'href': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF',
#   'id': '14hsjenLEdvafsGkk2CEiF',
#   'name': 'MC Fabinho da Osk',
#   'type': 'artist',
#   'uri': 'spotify:artist:14hsjenLEdvafsGkk2CEiF'}]

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_id)
# Out:
# 6xUYw5goKIoyJQi9C27UBy
# 0I7096R74VFP2xnMmp33sY
# 4s7LxMlh6RxgdMhldfMe8u
# 3bT53CJPMsSXSn0vDAX2Do
# 5fvUS8yHMCkTZj4sJ0FHDV
# 5D17Gk0J7jPXLvWMszqijF
# 2JCCZCrAWvohxlUXRRz36I
# 3gciIH7IvN83uLz6Ay983i
# 4ZopuwBxqYKDYkKh61tNqv
# 6dNugoBYWvUDQDtLurImhw
# 1kmsUHDC0n611meNgzRkuw
# 5g6rpHaTCaF9tXWfiHd2Cr
# 2VW8krMRkhGJmdlcHbyTfZ
# 0Qi6ZoqjRHB9W3yZl5Jb25
# 3JsABNfp6sTjgcawWxzmj7
# 7CWmZcjCHJWd7detYptzAX
# 2acEAXK1zIr0cPBkIDDJgz
# 62R2H85ZiKLp0lYHPprQWV
# 4FRxgE6LA2UGJ5yz8diaI9
# 6Zd0Hg3HKVH7xhBPgESQy1
# 1QFKbF3Oot9Ad1NnRCAG32
# 3tSeUNn7yOQPEex7jwS9Bf
# 4QmDrxVGw99LUJOubfPJz9
# 1qlnjo9SZtK01FqDyjv6nM
# 06a7H7nusNMvM7yL8m3fy1
# 5rDznSixlUXNxJySfWQNb7
# 1vQpZhp0nRdlUT4m2cgV4k
# 5n9EF7hP2GRMiklzLpPY0E
# 2Osz2h7ZjKHOZh5grL7o6G
# 1k9oQsBjwIhc4vF32zxvY5
# 27XmqsKeLyr5jDURAordcd
# 7JslfZtjZ430btdARyxLQ4
# 6DptPhwLku8xvWBodULnC6
# 1ILssfrknV8cQv5QvwBGUY
# 6tf2ziKDZQJinItJi99wBW
# 3BsuqyYCV0DYIBrDi1SKwQ
# 2EuOCirl08WxbRY2cfj4H5
# 3Iw0jAPzwgmuqSIWQa9i8W
# 1R1KJCX1oc3xqSbABo2Wpn
# 2bqWrlHmNh4M41xOr0p7iN
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_name)
# Out:
# NUNCA MUDA?
# PASSO BEM SOLTO
# Funk de Beleza
# DIA DELÍCIA
# Vem Vem
# MONTAGEM TOMADA
# COM MEDO!
# FUNK SIGILO
# MENTE MÁ
# X-TALI
# FUNK UNIVERSO
# MONTAGEM BATCHI
# MONTAGEM BAILÃO
# Amor Na Praia
# MONTAGEM XONADA
# LOS VOLTAJE
# LUNA BALA
# MTG - RITMO ZELDA
# FUNKED UP
# FUNK DO BOUNCE (Slowed)
# X-SLIDE
# GLORY
# SPOOKY
# EI DO SENSACIO!
# AURA
# REI DO BRASIL
# Mexican Phonk Eki
# AVANGARD (Slowed)
# BAIXO
# NEXT!
# TUCA DONKA
# PYTHON FUNK
# Orquestra Maldita
# DNA
# SPACE!
# Sequência da Dz7
# Life in Rio
# FUNK INFERNAL
# Montagem Injuriosum Retines (Slowed)
# Funk Secreto (Ultra Slowed)
# void
# BLUE HORIZON FUNK
# BLAH
# DON`T STOP
# SLAY!
# Beeper Funk (Slowed)
# FUNK DO BALKAN
# Ela Vira Mortal
# Death Is No More
# YUM YUM
# BAD PARENTING FUNK
# MANDA BALA
# RISADA CHUCK 01
# ICEWHORE!
# MONTAGEM DIAMANTE ROSA
# MTG - VINGANÇA
# VAPO NO SETOR
# Montagem Melodia Explosiva
# MASHA ULTRAFUNK
# z-beta 2
# MY TYPE
# BLOODY!
# freedom from self
# BOUNCE FUNK (Slowed)
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    print(album_element)
# Out:
# {'album_id': '6xUYw5goKIoyJQi9C27UBy', 'name': 'NUNCA MUDA?', 'release_date': '2025-01-09', 'total_tracks': 6, 'url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'}
# {'album_id': '0I7096R74VFP2xnMmp33sY', 'name': 'PASSO BEM SOLTO', 'release_date': '2024-04-23', 'total_tracks': 5, 'url': 'https://open.spotify.com/album/0I7096R74VFP2xnMmp33sY'}
# {'album_id': '4s7LxMlh6RxgdMhldfMe8u', 'name': 'Funk de Beleza', 'release_date': '2024-10-04', 'total_tracks': 3, 'url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'}
# {'album_id': '3bT53CJPMsSXSn0vDAX2Do', 'name': 'DIA DELÍCIA', 'release_date': '2025-04-25', 'total_tracks': 4, 'url': 'https://open.spotify.com/album/3bT53CJPMsSXSn0vDAX2Do'}
# {'album_id': '5fvUS8yHMCkTZj4sJ0FHDV', 'name': 'Vem Vem', 'release_date': '2025-05-30', 'total_tracks': 4, 'url': 'https://open.spotify.com/album/5fvUS8yHMCkTZj4sJ0FHDV'}
# ...

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'name': 'NUNCA MUDA?',
#   'release_date': '2025-01-09',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'},
#  {'album_id': '0I7096R74VFP2xnMmp33sY',
#   'name': 'PASSO BEM SOLTO',
#   'release_date': '2024-04-23',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0I7096R74VFP2xnMmp33sY'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'name': 'Funk de Beleza',
#   'release_date': '2024-10-04',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'},
#  {'album_id': '3bT53CJPMsSXSn0vDAX2Do',
#   'name': 'DIA DELÍCIA',
#   'release_date': '2025-04-25',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3bT53CJPMsSXSn0vDAX2Do'},
#  {'album_id': '5fvUS8yHMCkTZj4sJ0FHDV',
#   'name': 'Vem Vem',
#   'release_date': '2025-05-30',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5fvUS8yHMCkTZj4sJ0FHDV'},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dDNNq04RjKXFOADdHd6VX'},
#   'href': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX',
#   'id': '5dDNNq04RjKXFOADdHd6VX',
#   'name': 'Scythermane',
#   'type': 'artist',
#   'uri': 'spotify:artist:5dDNNq04RjKXFOADdHd6VX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7lAaAGxYxk2GH8cMbTEwAL'},
#   'href': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL',
#   'id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'name': 'NXGHT!',
#   'type': 'artist',
#   'uri': 'spotify:artist:7lAaAGxYxk2GH8cMbTEwAL'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/14hsjenLEdvafsGkk2CEiF'},
#   'href': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF',
#   'id': '14hsjenLEdvafsGkk2CEiF',
#   'name': 'MC Fabinho da Osk',
#   'type': 'artist',
#   'uri': 'spotify:artist:14hsjenLEdvafsGkk2CEiF'}]

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SCDfg1YoEfI5gFtXqEWah'},
#   'href': 'https://api.spotify.com/v1/artists/5SCDfg1YoEfI5gFtXqEWah',
#   'id': '5SCDfg1YoEfI5gFtXqEWah',
#   'name': 'ATLXS',
#   'type': 'artist',
#   'uri': 'spotify:artist:5SCDfg1YoEfI5gFtXqEWah'}]

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            print(value)
# Out:
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dDNNq04RjKXFOADdHd6VX'}, 'href': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX', 'id': '5dDNNq04RjKXFOADdHd6VX', 'name': 'Scythermane', 'type': 'artist', 'uri': 'spotify:artist:5dDNNq04RjKXFOADdHd6VX'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7lAaAGxYxk2GH8cMbTEwAL'}, 'href': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL', 'id': '7lAaAGxYxk2GH8cMbTEwAL', 'name': 'NXGHT!', 'type': 'artist', 'uri': 'spotify:artist:7lAaAGxYxk2GH8cMbTEwAL'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/14hsjenLEdvafsGkk2CEiF'}, 'href': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF', 'id': '14hsjenLEdvafsGkk2CEiF', 'name': 'MC Fabinho da Osk', 'type': 'artist', 'uri': 'spotify:artist:14hsjenLEdvafsGkk2CEiF'}]
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist['id'])
# Out:
# 5dDNNq04RjKXFOADdHd6VX
# 7lAaAGxYxk2GH8cMbTEwAL
# 14hsjenLEdvafsGkk2CEiF
# 5SCDfg1YoEfI5gFtXqEWah
# 3g0UoyvaTaHUrfpHiRqsD1
# 5dDNNq04RjKXFOADdHd6VX
# 10mKIVPFtg42JIvttHQrzr
# 1kd6WqngBvP0Vthu1sGI0j
# 3awueWqdp1OZudPelsEIgx
# 2Q3xviVw2VXFRXtsF2gpR1
# 2q5vFLZus8uaVSzmIwH4Tz
# 67PBOFpTBFaNkhz5IouBwi
# 7kk9ucvRJim0NMM89Lml2Y
# 6s4LSwgbzTAfnN6OUfegJB
# 5dDNNq04RjKXFOADdHd6VX
# 0exQbKNFd9pLmdIGycwmlf
# 1kd6WqngBvP0Vthu1sGI0j
# 3awueWqdp1OZudPelsEIgx
# 7qIgmxSjoXEeifSVDh8nIt
# 1dX1zejt24Ojiu0lX4T1ZM
# 0Vxqvpm9tpZcz6d4egDtjX
# 2vKxv2oKVSEJZ1VmuLUOvY
# 7kk9ucvRJim0NMM89Lml2Y
# 55TpSGABb9xsmXHkqbv3ti
# 0jrirfCZkRU3iA2sH9JEko
# 5SCDfg1YoEfI5gFtXqEWah
# 34giN3qeTOdgDSJIdtIMdm
# 5bePP411ITzZyWf1QZ2SX4
# 7kk9ucvRJim0NMM89Lml2Y
# 6U0dJxYVB41L8WDZ02Nwuk
# 0JGZRsRtFTQ0ZVBq9b2ZEj
# 6s4LSwgbzTAfnN6OUfegJB
# 02wf6SCDwrs2qTX09X0IRE
# 09cKncAQn28NqTUORLMwSR
# 02wf6SCDwrs2qTX09X0IRE
# 09cKncAQn28NqTUORLMwSR
# 2nGwC9QG6Hpw4fSDgNpn5n
# 4DWPOsGWbW7sBHb1UuBvWs
# 4nl0CCx6PpEOOr2Z2ThPdp
# 6JjQbtAO09K7qBEW2pdX5s
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id' :artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'artist_name': 'NXGHT!',
#   'external_url': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL'},
#  {'artist_id': '14hsjenLEdvafsGkk2CEiF',
#   'artist_name': 'MC Fabinho da Osk',
#   'external_url': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF'},
#  {'artist_id': '5SCDfg1YoEfI5gFtXqEWah',
#   'artist_name': 'ATLXS',
#   'external_url': 'https://api.spotify.com/v1/artists/5SCDfg1YoEfI5gFtXqEWah'},
#  {'artist_id': '3g0UoyvaTaHUrfpHiRqsD1',
#   'artist_name': 'Nateki',
#   'external_url': 'https://api.spotify.com/v1/artists/3g0UoyvaTaHUrfpHiRqsD1'},
#  {'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '10mKIVPFtg42JIvttHQrzr',
# ...

# %%
album_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 album_df.head()
#
# NameError: name 'album_df' is not defined

# %%
album_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 album_df.info()
#
# NameError: name 'album_df' is not defined

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 album_df = album_df.drop_duplicates(subset=['album_id'])
#
# NameError: name 'album_df' is not defined

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dDNNq04RjKXFOADdHd6VX'},
#   'href': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX',
#   'id': '5dDNNq04RjKXFOADdHd6VX',
#   'name': 'Scythermane',
#   'type': 'artist',
#   'uri': 'spotify:artist:5dDNNq04RjKXFOADdHd6VX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7lAaAGxYxk2GH8cMbTEwAL'},
#   'href': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL',
#   'id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'name': 'NXGHT!',
#   'type': 'artist',
#   'uri': 'spotify:artist:7lAaAGxYxk2GH8cMbTEwAL'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/14hsjenLEdvafsGkk2CEiF'},
#   'href': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF',
#   'id': '14hsjenLEdvafsGkk2CEiF',
#   'name': 'MC Fabinho da Osk',
#   'type': 'artist',
#   'uri': 'spotify:artist:14hsjenLEdvafsGkk2CEiF'}]

# %%
album_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 album_df.info()
#
# NameError: name 'album_df' is not defined

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  5dDNNq04RjKXFOADdHd6VX        Scythermane
# 1  7lAaAGxYxk2GH8cMbTEwAL             NXGHT!
# 2  14hsjenLEdvafsGkk2CEiF  MC Fabinho da Osk
# 3  5SCDfg1YoEfI5gFtXqEWah              ATLXS
# 4  3g0UoyvaTaHUrfpHiRqsD1             Nateki
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5dDNNq04RjK...
# 1  https://api.spotify.com/v1/artists/7lAaAGxYxk2...
# 2  https://api.spotify.com/v1/artists/14hsjenLEdv...
# 3  https://api.spotify.com/v1/artists/5SCDfg1YoEf...
# 4  https://api.spotify.com/v1/artists/3g0UoyvaTaH...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     148 non-null    object
#  1   artist_name   148 non-null    object
#  2   external_url  148 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     116 non-null    object
#  1   artist_name   116 non-null    object
#  2   external_url  116 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            print(value['name'])
# Out:
# NUNCA MUDA?
# PASSO BEM SOLTO - Slowed
# Funk de Beleza - Slowed
# DIA DELÍCIA
# Vem Vem
# MONTAGEM TOMADA - Slowed
# COM MEDO!
# FUNK SIGILO - ULTRA SLOWED
# MENTE MÁ
# X-TALI
# FUNK UNIVERSO
# MONTAGEM BATCHI
# MONTAGEM BAILÃO
# Amor Na Praia
# MONTAGEM XONADA
# LOS VOLTAJE
# LUNA BALA - Slowed
# MTG - RITMO ZELDA - Super Slowed
# FUNKED UP - SLOWED
# FUNK DO BOUNCE (Slowed)
# X-SLIDE
# GLORY
# SPOOKY
# EI DO SENSACIO!
# AURA
# REI DO BRASIL
# Mexican Phonk Eki
# AVANGARD - Slowed
# BAIXO
# NEXT!
# TUCA DONKA
# PYTHON FUNK
# Orquestra Maldita
# DNA
# SPACE! - Super Slowed
# Sequência da Dz7
# Life in Rio
# FUNK INFERNAL
# Montagem Injuriosum Retines - Slowed
# Funk Secreto - Ultra Slowed
# void - super slowed
# BLUE HORIZON FUNK - SLOWED
# BLAH
# DON`T STOP - Slowed
# SLAY!
# Beeper Funk - Slowed
# FUNK DO BALKAN - Slowed
# Ela Vira Mortal
# Death Is No More
# YUM YUM
# BAD PARENTING FUNK
# MANDA BALA
# RISADA CHUCK 01 - Super Slowed
# ICEWHORE!
# MONTAGEM DIAMANTE ROSA
# ...

# %%
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:# when printing only artist, there you can see the next elements in
                #dictionary,which inlcudes 'name'
                print(artist['name'])
# Out:
# Scythermane
# NXGHT!
# MC Fabinho da Osk
# ATLXS
# Nateki
# Scythermane
# MC MAYAH
# Nakama
# Mc Staff
# ΣP
# Jmilton
# MC Xangai
# MXZI
# Sayfalse
# Scythermane
# h6itam
# Nakama
# Mc Staff
# MXCCREE
# DJ GL3CHEKY
# MC PR
# Irokz
# MXZI
# Rushex
# Repsaj
# ATLXS
# Mc Jhey
# Flame Runner
# MXZI
# Dj Samir
# DJ Javi26
# Sayfalse
# Yb Wasg'ood
# Ariis
# Yb Wasg'ood
# Ariis
# JXM
# Polaris
# xxanteria
# isq
# Ariis
# 2KE
# 808iuli
# Ogryzek
# fennecxx
# DJ ALEX
# princce
# FR3ST
# Ogryzek
# Seek
# NUEKI
# TOLCHONOV
# LONOWN
# xxanteria
# NCTS
# CURSEDEVIL
# DJ FKU
# Skorde
# RD12
# Sayfalse
# TRASHXRL
# Mc Delux
# LXNGVX
# VISXGE
# NAOMI
# TRASHXRL
# Mc Menor Do Alvorada
# Slowboy
# NUEKI
# Crazy Mano
# TOLCHONOV
# DYGO
# Mxng0
# DJ JEEAN 011
# MC BM OFICIAL
# h6itam
# STRAWANGLE
# MC RP VK
# MC Da 12
# isq
# NXGHT!
# DJ ANXVAR
# DJ ZAP
# Hexora
# Artox
# Alert
# GLXXMSTRIDER
# Eternxlkz
# DJ Paulinho Mondi Da Baixa Baviera
# Mc Vitorioso
# $werve
# FXRCE
# Mc Denny
# DJ Vilão DS
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 album_df['release_date'] = pd.to_datetime(album_df['release_date'])
#
# NameError: name 'album_df' is not defined

# %%
album_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 album_df.info()
#
# NameError: name 'album_df' is not defined
